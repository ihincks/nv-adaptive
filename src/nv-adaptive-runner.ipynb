# %% [markdown]
# # Testing Adaptive Learning with Simulations

# %% [markdown]
# ### Import Modules

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('default', category=DeprecationWarning, module='.*/qinfer/.*')
from __future__ import division # Ensures that a/b is always a float.

# %%
import os
import itertools
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import qinfer as qi
import models as m
import abc
import datetime

reload(m)
# Out:
# <module 'models' from 'models.pyc'>

# %%
from ipyparallel import Client
rc = Client()
dview = rc[:]
dview.use_dill()

with dview.sync_imports():
    import os

# Change directory on engines so that we can import models.
if dview.execute('os.chdir("{}")'.format(os.getcwd())).get():
    print "Changed engine directories to notebook directory."

# To ensure that we don't enter into a Matplotlib event loop
# on our engines, we set the MPLBACKEND to the non-interactive
# Agg backend first. This is especially useful if the engines
# are connected via SSH.
if dview.execute('os.environ["MPLBACKEND"] = "Agg"').get():
    print "Changed MPL backend."

# Force each engine to import QInfer before proceeding.
if dview.execute('import qinfer as qi').get():
    print "Successfully imported QInfer on engines."

if dview.execute('import models').get():
    print "Successfully imported models."

print "Engines connected: {}".format(len(rc.ids))
# Out:
# importing os on engine(s)
# Changed engine directories to notebook directory.
# Changed MPL backend.
# Successfully imported QInfer on engines.
# Successfully imported models.
# Engines connected: 12

# %% [markdown]
# ### Setup

# %% [markdown]
# Plotting and exporting. Change the `overwrite` flag if you want regenerated figures to be saved to disk.

# %%
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

SIZE = 14
plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)     # fontsize of the x any y labels
plt.rc('xtick', labelsize=10)      # fontsize of the tick labels
plt.rc('ytick', labelsize=10)      # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)   # size of the figure title

overwrite = True
def export_figure(fig, name, extensions=['.png', '.pdf']):
    for ext in extensions:
        fname = '../fig/' + name + ext
        if not os.path.isfile(fname):
            print('Saving {}'.format(fname))
            fig.savefig(fname)
        elif overwrite:
            print('Overwriting {}'.format(fname))
            fig.savefig(fname)
        else:
            print('Skipping {}'.format(fname))

# %% [markdown]
# ### Stochastic Process Simulators

# %%
class StochasticStepper(object):
    def __init__(self):
        self._x = None
        self._history = []
        self.reset()
    def _set_value(self, value):
        self._x = value
        self._history.append(self._x)
    @property
    def value(self):
        return self._x
    @property
    def history(self):
        return np.array(self._history)
    @abc.abstractmethod
    def step(self):
        pass
    @abc.abstractmethod
    def reset(self):
        pass

class OrnsteinUhlenbeckStepper(StochasticStepper):
    def __init__(self, mu, sigma, theta, x0, sigma_x0):
        self.x0 = x0
        self.sigma_x0 = sigma_x0
        self.mu = mu
        self.sigma = sigma
        self.theta = theta
        super(OrnsteinUhlenbeckStepper, self).__init__()
        
    def step(self, time):
        eps = np.sqrt(time) * np.random.randn()
        new_x = self._x + self.theta * (self.mu - self._x) * time + self.sigma * eps
        self._set_value(new_x)
        
    def reset(self):
        self._set_value(self.x0 + self.sigma_x0 * np.random.randn(1))
        
class NVDriftStepper(StochasticStepper):
    def __init__(self, 
                 mu_alpha=0.01, sigma_alpha=0.0005, 
                sigma_nu=5e-5, theta_nu=0.005, 
                mu_kappa=0.33, sigma_kappa=0.01, theta_kappa=0.01,
                background=0.003
            ):
        self._background = background
        self._nu = OrnsteinUhlenbeckStepper(0, sigma_nu, theta_nu, mu_alpha - background, sigma_alpha)
        self._kappa = OrnsteinUhlenbeckStepper(mu_kappa, sigma_kappa, theta_kappa, 0, 0)
        super(NVDriftStepper, self).__init__()
    
    def _set_value(self):
        super(NVDriftStepper, self)._set_value(
            np.array([
                self._background + self._nu.value, 
                self._background + self._kappa.value * self._nu.value
            ]).flatten()
        )
        
    def step(self, time):
        self._kappa.step(time)
        self._nu.step(time)
        self._set_value()
        
    def reset(self):
        self._kappa.reset()
        self._nu.reset()
        self._set_value()

# %%
drift = NVDriftStepper()
for idx in range(100):
    drift.step(1)
plt.plot(drift.history)
plt.ylim([0,0.015])
# Out:
# (0, 0.015)

# %% [markdown]
# ### Initialize Prior and Sweeps

# %% [markdown]
# Model parameters:
#    - 0: :math:`\Omega`, Rabi strength (MHz); coefficient of Sx
#    - 1: :math:`\omega_e`, Zeeman frequency (MHz); coefficient of Sz
#    - 2: :math:`\Delta \omega_c`, ZFS detuning (MHz); coefficient of Sz^2
#    - 3: :math:`\A_N`, Nitrogen hyperfine splitting (MHz); modeled as incoherent average
#    - 4: :math:`T_2^-1`, inverse of electron T2* (MHz)
#
# Experiment parameters:
#  - mode: Specifies whether a reference or signal count is being performed.
#  - t:   Pulse width
#  - tau: Ramsey wait time (only relevent if mode is `RabiRamseyModel.RAMSEY`)
#  - phi: Ramsey phase between pulses (")
#  - wo: Carrier offset from 2870MHz, positive or negative (MHz)

# %%
true_value = np.array([5.555, 1.432, 0.579, 2.171, 0.25])
target_stds = np.array([0.01,0.005,0.01,0.005,0.01])
wide_prior = qi.UniformDistribution(np.array([
            [0,10],
            [0,10],
            [-5,5],
            [1.5,3.5],
            [100**-1,1**-1]
        ]))
narrow_prior = qi.UniformDistribution(
    true_value[:,np.newaxis] + 
    target_stds[:,np.newaxis]*([-1,1]*np.ones((5,2)))
)
medium_prior = qi.UniformDistribution(
    true_value[:,np.newaxis] + 
    10*target_stds[:,np.newaxis]*([-1,1]*np.ones((5,2)))
)

drift_prior = qi.UniformDistribution(
    [[0.008,0.0012],[0.002,0.005],[0,0.0001],[0,0.0001],[0,0.00001]]
)

# %%
ham_model = m.RabiRamseyModel()
ref_model = m.ReferencedPoissonModel(ham_model)
def rabi_sweep(min_t=None, max_t=0.3, n=50, n_meas=None, wo=0, mode=None):
    if min_t is None:
        min_t = max_t / n
    vals = [
        np.linspace(min_t, max_t, n),
        np.zeros(n),
        np.zeros(n),
        np.ones(n) * wo,
        np.ones(n) * ham_model.RABI
    ]
    dtype = ham_model.expparams_dtype
    if n_meas is not None:
        mode = ref_model.SIGNAL if mode is None else mode
        vals = vals + [(mode * np.ones(n)).astype(np.int)]
        vals = vals + [(n_meas * np.ones(n)).astype(np.int)]
        dtype = dtype + [('mode', 'int'),('n_meas','int')]
    rabi_eps = np.array(vals).T
    rabi_eps = np.array(list(zip(*rabi_eps.T)), dtype=dtype)
    return rabi_eps

def ramsey_sweep(min_tau=None, max_tau=2, tp=0.01, phi=0, n=50, n_meas=None, wo=0, mode=None):
    if min_tau is None:
        min_tau = max_tau / n
    vals = [
        tp * np.ones(n),
        np.linspace(min_tau, max_tau, n),
        phi * np.ones(n),
        np.ones(n) * wo,
        np.ones(n) * ham_model.RAMSEY
    ]
    dtype = ham_model.expparams_dtype
    if n_meas is not None:
        mode = ref_model.SIGNAL if mode is None else mode
        vals = vals + [(mode * np.ones(n)).astype(np.int)]
        vals = vals + [(n_meas * np.ones(n)).astype(np.int)]
        dtype = dtype + [('mode', 'int'),('n_meas','int')]
    ramsey_eps = np.array(vals).T
    ramsey_eps = np.array(list(zip(*ramsey_eps.T)), dtype=dtype)
    return ramsey_eps

# %% [markdown]
# ### Experiment Runners

# %%
class ExperimentResult(object):
    def __init__(self, bright, dark, signal, timestamp=None):
        self._bright = bright
        self._dark = dark
        self._signal = signal
        self._timestamp = datetime.datetime.now() if timestamp is None else timestamp
        
    @property
    def bright(self):
        return self._bright
    @property
    def dark(self):
        return self._dark
    @property
    def signal(self):
        return self._signal
    @property
    def timestamp(self):
        return self._timestamp
    @property
    def triplet(self):
        return np.array([self.bright, self.dark, self.signal])

class AbstractRabiRamseyExperimentRunner(object):
    
    def __init__(self):
        self._experiment_history = None
        
    def append_experiment_to_history(self, expparam):
        eps = np.atleast_1d(expparam)
        if self._experiment_history is None:
            self._experiment_history = eps
        else:
            self._experiment_history = np.concatenate([self._experiment_history, eps])
    
    @property
    def experiment_history(self):
        return self._experiment_history
    
    @abc.abstractmethod
    def run_experiment(self, expparam):
        self.append_experiment_to_history(expparam)
        
    @abc.abstractmethod
    def run_tracking(self):
        pass
    
def experiment_time(expparam):
    extra_time_per_shot = 20e-6
    extra_time_per_experiment = 0.6
    if expparam['emode'] == ham_model.RABI:
        t_experiment = expparam['t']
    else:
        t_experiment = expparam['tau'] + 2 * exparam['t']
    return expparam['mode'] * (t_experiment + extra_time_per_shot) \
            + extra_time_per_experiment
        
class SimulatedRabiRamseyExperimentRunner(AbstractRabiRamseyExperimentRunner):
    def __init__(self, hamparam, drift=None):
        super(SimulatedRabiRamseyExperimentRunner, self).__init__()
        
        self._ham_param = hamparam
        self._ham_model = m.RabiRamseyModel()
        self._model = m.ReferencedPoissonModel(self._ham_model)
        #qi.DirectViewParallelizedModel(
        #    m.ReferencedPoissonModel(self._ham_model), 
        #    dview, 
        #    serial_threshold=1
        #)

        self.drift = NVDriftStepper() if drift is None else drift

    @property
    def modelparam(self):
        return np.atleast_2d(np.concatenate([self._ham_param, self.drift.value]))
    
    def update_timestep(self, expparam):
        self.drift.step(experiment_time(expparam))
        
    def run_tracking(self):
        self.drift.reset()
        
    def run_experiment(self, expparam):
        super(SimulatedRabiRamseyExperimentRunner, self).run_experiment(expparam)
        self.update_timestep(expparam)
        expparam['mode'] = ref_model.BRIGHT
        bright = self._model.simulate_experiment(self.modelparam, expparam)
        expparam['mode'] = ref_model.DARK
        dark = self._model.simulate_experiment(self.modelparam, expparam)
        expparam['mode'] = ref_model.SIGNAL
        signal = self._model.simulate_experiment(self.modelparam, expparam)
        return ExperimentResult(bright, dark, signal)

# %%
sim = SimulatedRabiRamseyExperimentRunner(true_value)
rabi_eps = rabi_sweep(max_t=0.3,n=50,n_meas=100000)
results = np.empty((rabi_eps.size, 3))
for idx, eps in enumerate(rabi_eps):
    results[idx,:] = sim.run_experiment(np.atleast_1d(eps)).triplet
plt.plot(results)
# Out:
# [<matplotlib.lines.Line2D at 0x111254550>,
#  <matplotlib.lines.Line2D at 0x111254310>,
#  <matplotlib.lines.Line2D at 0x1112540d0>]

# %% [markdown]
# ### Heuristics

# %%
class RiskHeuristic(qi.Heuristic):
    def __init__(self, updater, Q, rabi_eps, ramsey_eps, name=None):
        self.updater = updater
        self._ham_model = qi.DirectViewParallelizedModel(m.RabiRamseyModel(), dview, serial_threshold=1)
        self._ham_model._Q = Q
        self._risk_taker = qi.SMCUpdater(self._ham_model, updater.n_particles, wide_prior)
        self._update_risk_particles()
        self._rabi_eps = rabi_eps
        self._ramsey_eps = ramsey_eps
        self.name = "Bayes Risk, Q={}".format(Q) if name is None else name
        self.risk_history = []
        
    def _update_risk_particles(self):
        self._risk_taker.particle_locations = self.updater.particle_locations
        self._risk_taker.particle_weights = self.updater.particle_weights
        
    def __call__(self, tp):
        ramsey_eps = self._ramsey_eps
        ramsey_eps['t'] = tp
        all_eps = np.concatenate([self._rabi_eps, ramsey_eps])
        
        self._update_risk_particles()
        
        risk = self._risk_taker.bayes_risk(all_eps)
        self.risk_history += [risk]
        best_idx = np.argmin(risk, axis=0)
        eps = np.array([all_eps[best_idx]])
        return eps
    
class InfoGainHeuristic(qi.Heuristic):
    def __init__(self, updater, rabi_eps, ramsey_eps, name=None):
        self.updater = updater
        self._ham_model = qi.DirectViewParallelizedModel(m.RabiRamseyModel(), dview, serial_threshold=1)
        self._risk_taker = qi.SMCUpdater(self._ham_model, updater.n_particles, wide_prior)
        self._update_risk_particles()
        self._rabi_eps = rabi_eps
        self._ramsey_eps = ramsey_eps
        self.name = "Expected Information Gain" if name is None else name
        self.risk_history = []
        
    def _update_risk_particles(self):
        self._risk_taker.particle_locations = self.updater.particle_locations
        self._risk_taker.particle_weights = self.updater.particle_weights
        
    def __call__(self, tp):
        ramsey_eps = self._ramsey_eps
        ramsey_eps['t'] = tp
        all_eps = np.concatenate([self._rabi_eps, ramsey_eps])
        
        self._update_risk_particles()
        
        eig = self._risk_taker.expected_information_gain(all_eps)
        self.risk_history += [eig]
        best_idx = np.argmax(eig, axis=0)
        eps = np.array([all_eps[best_idx]])
        return eps
    
class ExponentialHeuristic(qi.Heuristic):
    def __init__(self, updater, max_t=0.3, max_tau=2, base=11/10, n=50, n_bin=100, name=None):
        self.updater = updater
        self._rabi_eps = rabi_sweep(max_t=1, n=n, n_bin=n_bin)
        self._ramsey_eps = ramsey_sweep(max_tau=1, n=n, n_bin=n_bin)
        
        self._rabi_eps['t'] = max_t * (base ** np.arange(n)) / (base ** (n-1))
        self._ramsey_eps['tau'] = max_tau * (base ** np.arange(n)) / (base ** (n-1))
        
        self._rabi_eps['t'] = np.round(self._rabi_eps['t'] / 0.002) * 0.002
        self._ramsey_eps['tau'] = np.round(self._ramsey_eps['tau'] / 0.002) * 0.002
        
        self._idx = 0
        self.name = "Exponentially Sparse Heur" if name is None else name
        
    def __call__(self, tp):
        ramsey_eps = self._ramsey_eps
        ramsey_eps['t'] = tp
        all_eps = np.vstack([self._rabi_eps, ramsey_eps]).reshape((-1,), order='F')
        
        eps =  np.array([all_eps[self._idx]])
        self._idx += 1
        return eps
    
class LinearHeuristic(qi.Heuristic):
    def __init__(self, updater, max_t=0.3, max_tau=2, n=50, n_bin=100, name=None):
        self.updater = updater
        self._rabi_eps = rabi_sweep(max_t=1, n=n, n_bin=n_bin)
        self._ramsey_eps = ramsey_sweep(max_tau=1, n=n, n_bin=n_bin)
        
        self._rabi_eps['t'] = np.round(self._rabi_eps['t'] / 0.002) * 0.002
        self._ramsey_eps['tau'] = np.round(self._ramsey_eps['tau'] / 0.002) * 0.002
        
        self._idx = 0
        self.name = "Standard Linear Heuristic" if name is None else name
        
    def __call__(self, tp):
        ramsey_eps = self._ramsey_eps
        ramsey_eps['t'] = tp
        all_eps = np.vstack([self._rabi_eps, ramsey_eps]).reshape((-1,), order='F')
        
        eps =  np.array([all_eps[self._idx]])
        self._idx += 1
        return eps

# %% [markdown]
# ### Adaptive Simulations

# %%
n_meas = 100000
n_particles = 2000
n_experiments = 100
n_trials = 1

sim = SimulatedRabiRamseyExperimentRunner(true_value)

def make_updater():
    return qi.DirectViewParallelizedModel(
        qi.GaussianRandomWalkModel(
            m.ReferencedPoissonModel(m.RabiRamseyModel()),
            random_walk_idxs=[5,6],
            diagonal=False,
            scale_mult=experiment_time
        ), 
        dview, 
        serial_threshold=1
    )

Q = np.array([1,1,0,0,0])

heuristics = []

track_means = np.zeros((n_trials, n_experiments + 1, 10))
track_covs = np.zeros((n_trials, n_experiments + 1, 10, 10))

for idx_trial in range(n_trials):
    heuristic = RiskHeuristic(
        qi.SMCUpdater(make_updater(), n_particles, qi.ProductDistribution(wide_prior,drift_prior)), 
        Q, 
        rabi_sweep(max_t=0.5, n=50, n_meas=n_meas), 
        ramsey_sweep(max_tau=2, n=50, n_meas=n_meas)
    )
    heuristics.append(heuristic)
    updater = heuristic.updater

    track_means[idx_trial, 0, :] = heuristic.updater.est_mean()
    track_covs[idx_trial, 0, :, :] = heuristic.updater.est_covariance_mtx()

    for idx_eps in range(n_experiments):

        #estimate ramsey pulse time
        current_est = updater.est_mean()
        tp_est = np.round(1 / current_est[0] / 4 / 0.002) * 0.002

        #decide experiment
        eps = heuristic(tp_est)
        print("{}: {} : {}".format(idx_eps, heuristic.name, eps[0])), np.round(1000 * np.sqrt(np.diag(updater.est_covariance_mtx())))

        # simulate outcome
        outcome = sim.run_experiment(eps)

        # update
        eps['mode'] = ref_model.BRIGHT
        bright = updater.update(outcome.bright, eps)
        eps['mode'] = ref_model.DARK
        dark = updater.update(outcome.dark, eps)
        eps['mode'] = ref_model.SIGNAL
        signal = updater.update(outcome.signal, eps)

        # store info
        track_means[idx_trial, idx_eps + 1, :] = updater.est_mean()
        track_covs[idx_trial, idx_eps + 1, :, :] = updater.est_covariance_mtx()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-bb8b223499a7> in <module>()
#      45
#      46         #decide experiment
# ---> 47         eps = heuristic(tp_est)
#      48         print("{}: {} : {}".format(idx_eps, heuristic.name, eps[0])), np.round(1000 * np.sqrt(np.diag(updater.est_covariance_mtx())))
#      49
#
# <ipython-input-85-231e7eef8351> in __call__(self, tp)
#      22         self._update_risk_particles()
#      23
# ---> 24         risk = self._risk_taker.bayes_risk(all_eps)
#      25         self.risk_history += [risk]
#      26         best_idx = np.argmin(risk, axis=0)
#
# /Users/ihincks/miniconda2/envs/nvmeas/lib/python2.7/site-packages/qinfer/smc.pyc in bayes_risk(self, expparams)
#     594                 self.particle_locations[np.newaxis,np.newaxis,:,:] -
#     595                 mu_hyp[:,:,np.newaxis,:]
# --> 596             ) ** 2,  axis=3),
#     597             axis=2
#     598         )
#
# ValueError: operands could not be broadcast together with shapes (5,) (2,100,2000,10)

# %%
idx_model = 0
fig=plt.figure(figsize=(10,5))
for idx_h in range(n_updaters):
    h = heuristics[0][idx_h]
    plt.semilogy(np.mean(np.sqrt(track_covs[:,idx_h,:,idx_model,idx_model]),axis=0), label=h.name)
plt.legend(bbox_to_anchor=(1.05, 1.05))
plt.title('${}$'.format(ham_model.modelparam_names[idx_model]))
plt.xlabel('Experiment #')
plt.ylabel('std (MHz)')
export_figure(fig, 'qhl-wr-variance')
# Out:
# Overwriting ../fig/qhl-wr-variance.png
# Overwriting ../fig/qhl-wr-variance.pdf

# %%
idx_model = 1
fig=plt.figure(figsize=(10,5))
for idx_h in range(n_updaters):
    h = heuristics[0][idx_h]
    plt.semilogy(np.mean(np.sqrt(track_covs[:,idx_h,:,idx_model,idx_model]),axis=0), label=h.name)
plt.legend(bbox_to_anchor=(1.05, 1.05))
plt.title('${}$'.format(ham_model.modelparam_names[idx_model]))
plt.xlabel('Experiment #')
plt.ylabel('std (MHz)')
export_figure(fig, 'qhl-we-variance')
# Out:
# Overwriting ../fig/qhl-we-variance.png
# Overwriting ../fig/qhl-we-variance.pdf

# %%
idx_model = 3
fig=plt.figure(figsize=(10,5))
for idx_h in range(n_updaters):
    h = heuristics[0][idx_h]
    plt.semilogy(np.mean(np.sqrt(track_covs[:,idx_h,:,idx_model,idx_model]),axis=0), label=h.name)
plt.legend(bbox_to_anchor=(1.05, 1.05))
plt.title('${}$'.format(ham_model.modelparam_names[idx_model]))
plt.xlabel('Experiment #')
plt.ylabel('std (MHz)')
export_figure(fig, 'qhl-AN-variance')
# Out:
# Overwriting ../fig/qhl-AN-variance.png
# Overwriting ../fig/qhl-AN-variance.pdf

# %% [markdown]
# ### Lookahead Heuristic

# %% [markdown]
# It would be beneficial to do risk calculations at the same time as experiments, since both tasks are time consuming. The problem, however, is that calculating the best next experiment to do next relies on the latest data, which we would not have if we are doing experiments and calculations concurrently. Three ideas:
#  - Scrap concurrency, and just alternate between experiments and next best experiment simulations
#  - Choose the next experiment based on the previous posterior, so that one is always slightly out of touch
#  - Marginalize the heuristic over the hypothetical outcomes of the currently running experiment

# %%
def lookahead_bayes_risk(updater, first_expparams, second_expparams):
    
    # assume n_out1==n_out2==n_out for convenience
    n_out = updater.model.n_outcomes(np.atleast_1d(first_expparams)[0])
    n_eps1 = first_expparams.size
    n_eps2 = second_expparams.size
    
    # compute all likelihoods
    # the likelihood over outcomes should sum to 1, so don't compute for last outcome for efficiency
    L = updater.model.likelihood(
            np.arange(n_out-1), 
            updater.particle_locations,
            np.concatenate([first_expparams, second_expparams])
        )
    L = np.concatenate([L, (1 - L.sum(axis=0))[np.newaxis, ...]], axis=0).transpose((0,2,1))
    L1 = L[:, :first_expparams.size, :]              # L1.shape == (n_out1, n_eps1, n_particles)
    L2 = L[:, first_expparams.size:, :]              # L1.shape == (n_out2, n_eps2, n_particles)
    
    # compute the hypothetical posterior weights after the first hypothetical experiments, w_hyp1
    # and compute the hypothetical outcome probabilities, N1
    w_hyp1 = L1 * updater.particle_weights[np.newaxis, np.newaxis, :]
    
    # compute the hypothetical posterior weights after all 
    # combinations of first and second expparams and outcomes
    w_hyp12 = w_hyp1[:, np.newaxis, :,  np.newaxis, :] * L2[np.newaxis, :, np.newaxis, :, :]
    N12 = np.sum(w_hyp12, axis=4)                    # N12.shape = (n_out1, n_out2, n_eps1, n_eps2)
    w_hyp12 = w_hyp12 / N12[:, :, :, :, np.newaxis]  # w_hyp12.shape = (n_out1, n_out2, n_eps1, n_eps2, n_particles)

    # compute the hypothetical means and variances given outcomes and exparams
    # mu_hyp12.shape == (n_out1, n_out2, n_eps1, n_eps2, n_models)
    # var_hyp12.shape == (n_out1, n_out2, n_eps1, n_eps2)
    mu_hyp12 = np.dot(w_hyp12, updater.particle_locations)
    var_hyp12 = np.sum(
        w_hyp12 * 
        np.sum(updater.model.Q * (
            updater.particle_locations[np.newaxis, np.newaxis,np.newaxis,np.newaxis,:,:] - 
            mu_hyp12[:,:,:,:,np.newaxis,:]
        ) ** 2,  axis=5),
        axis=4
    )
    
    # the risk of a given expparam can be calculated as the mean posterior
    # variance weighted over all possible outcomes
    return np.sum(np.sum(N12 * var_hyp12, axis=0), axis=0)

class LookAheadRiskHeuristic(qi.Heuristic):
    def __init__(self, updater, Q, rabi_eps, ramsey_eps, name=None):
        self.updater = updater
        if not parallel:
            self._ham_model = m.RabiRamseyModel()
        else:
            self._ham_model = qi.DirectViewParallelizedModel(m.RabiRamseyModel(), dview, serial_threshold=1)
        self._ham_model._Q = Q
        self._risk_taker = qi.SMCUpdater(self._ham_model, updater.n_particles, wide_prior)
        self._update_risk_particles()
        self._rabi_eps = rabi_eps
        self._ramsey_eps = ramsey_eps
        self.name = "Look-Ahead Bayes Risk, Q={}".format(Q) if name is None else name
        self.risk_history = []
        
    def _update_risk_particles(self):
        self._risk_taker.particle_locations = self.updater.particle_locations
        self._risk_taker.particle_weights = self.updater.particle_weights
        
    def __call__(self, current_eps, tp):
        ramsey_eps = self._ramsey_eps
        ramsey_eps['t'] = tp
        all_eps = np.concatenate([self._rabi_eps, ramsey_eps])
        
        self._update_risk_particles()
        
        risk = lookahead_bayes_risk(self._risk_taker, current_eps, all_eps)[0,:]
        self.risk_history += [risk]
        best_idx = np.argmin(risk, axis=0)
        eps = np.array([all_eps[best_idx]])
        return eps

# %%
updater = qi.SMCUpdater(qi.DirectViewParallelizedModel(ham_model,dview), 5000, medium_prior)
rabi_eps = rabi_sweep(max_t=0.3,n=50)
ramsey_eps = ramsey_sweep(max_tau=2,n=50)
# %timeit -n1 -r1 lookahead_bayes_risk(updater, rabi_eps[4,np.newaxis], rabi_eps)
# %timeit -n1 -r1 updater.bayes_risk(rabi_eps)
# Out:
# 1 loop, best of 1: 904 ms per loop
# 1 loop, best of 1: 847 ms per loop

# %%
updater = qi.SMCUpdater(qi.DirectViewParallelizedModel(ham_model,dview), 5000, medium_prior)
rabi_eps = rabi_sweep(max_t=0.3,n=50)
ramsey_eps = ramsey_sweep(max_tau=2,n=50)
lbr = lookahead_bayes_risk(updater, rabi_eps, rabi_eps)
fig = plt.figure()
plt.imshow(lbr, extent=[np.min(ramsey_eps['tau']),np.max(ramsey_eps['tau']),np.min(ramsey_eps['tau']),np.max(ramsey_eps['tau'])])
plt.title('Look-ahead Bayes Risk for \nback-to-back Ramsey Experiments')
plt.xlabel('Ramsey #1 t $(\mu s)$')
plt.ylabel('Ramsey #2 t $(\mu s)$')
export_figure(fig, 'risk-look-ahead')
# Out:
# Overwriting ../fig/risk-look-ahead.png
# Overwriting ../fig/risk-look-ahead.pdf

# %%
n_bin = 10
n_particles = 2000
n_experiments = 100
n_trials = 50

def make_updater():
    if not parallel:
        return qi.BinomialModel(m.RabiRamseyModel())
    else:
        return qi.DirectViewParallelizedModel(qi.BinomialModel(m.RabiRamseyModel()), dview, serial_threshold=1)

Q = np.array([1,1,0,0,0])
n_updaters=3

heuristics_hal = []

track_means_lah = np.zeros((n_trials, n_updaters, n_experiments + 1, 5))
track_covs_lah = np.zeros((n_trials, n_updaters, n_experiments + 1, 5, 5))

for idx_trial in range(n_trials):
    print "Starting Trial {}".format(idx_trial)
    print "================="
    
    heuristics_hal.append([])
    heuristics_hal[-1] = [
        RiskHeuristic(
            qi.SMCUpdater(make_updater(), n_particles, wide_prior), 
            Q, 
            rabi_sweep(max_t=0.5, n=50, n_bin=n_bin), 
            ramsey_sweep(max_tau=2, n=50, n_bin=n_bin),
            name='Bayes Risk: Alternating    '
        ),
        RiskHeuristic(
            qi.SMCUpdater(make_updater(), n_particles, wide_prior), 
            Q, 
            rabi_sweep(max_t=0.5, n=50, n_bin=n_bin), 
            ramsey_sweep(max_tau=2, n=50, n_bin=n_bin),
            name='Bayes Risk: Old Information'
        ),
        LookAheadRiskHeuristic(
            qi.SMCUpdater(make_updater(), n_particles, wide_prior), 
            Q, 
            rabi_sweep(max_t=0.5, n=50, n_bin=n_bin), 
            ramsey_sweep(max_tau=2, n=50, n_bin=n_bin),
            name='Bayes Risk: Look-Ahead     '
        ),
    ]
    
    for idx_h, h in enumerate(heuristics_hal[-1]):
        track_means_lah[idx_trial,idx_h, 0, :] = h.updater.est_mean()
        track_covs_lah[idx_trial,idx_h, 0, :, :] = h.updater.est_covariance_mtx()
        
    # heuristics 1 and 2 require an initial experiment to run
    eps0 = None
    current_est = heuristics_hal[-1][1].updater.est_mean()
    tp_est = np.round(1 / current_est[0] / 4 / 0.002) * 0.002
    eps1 = heuristics_hal[-1][1](tp_est)
    eps2 = eps1

    for idx_eps in range(n_experiments):

        #--------------------------------------------------------------------
        # Alternating Heuristic: alternate experiments with risk optimization
        
        idx = 0
        heuristic = heuristics_hal[-1][idx]
        updater = heuristic.updater
        #estimate ramsey pulse time
        current_est = updater.est_mean()
        tp_est = np.round(1 / current_est[0] / 4 / 0.002) * 0.002
        #decide experiment
        eps0 = heuristic(tp_est)
        print("{}: {} : {}".format(idx_eps, heuristic.name, eps0[0])), np.round(1000 * np.sqrt(np.diag(updater.est_covariance_mtx())))
        # simulate outcome
        outcome = updater.model.simulate_experiment(true_value[np.newaxis,:], eps0)
        # update
        updater.update(outcome, eps0)
        
        #--------------------------------------------------------------------
        # Old Info Heuristic:    compute risk concurrently, but on the old 
        #                        posterior
        
        idx = 1
        heuristic = heuristics_hal[-1][idx]
        updater = heuristic.updater
        # simulate outcome _before_ knowing best thing to do
        outcome = updater.model.simulate_experiment(true_value[np.newaxis,:], eps1)
        # "simultaneously" decide next experiment based on old distribution
        current_est = updater.est_mean()
        tp_est = np.round(1 / current_est[0] / 4 / 0.002) * 0.002
        eps1_new = heuristic(tp_est)
        print("{}: {} : {}".format(idx_eps, heuristic.name, eps1_new[0])), np.round(1000 * np.sqrt(np.diag(updater.est_covariance_mtx())))
        # now both the experiment and the simulation are done, do the update
        updater.update(outcome, eps1)
        eps1 = eps1_new
        
        #--------------------------------------------------------------------
        # Look-Ahead Heuristic:  Take into account what we expect from the 
        #                        currently running experiment
        
        idx = 2
        heuristic = heuristics_hal[-1][idx]
        updater = heuristic.updater
        # simulate outcome _before_ knowing best thing to do
        outcome = updater.model.simulate_experiment(true_value[np.newaxis,:], eps2)
        # "simultaneously" decide next experiment based on old distribution and currently running experiment
        current_est = updater.est_mean()
        tp_est = np.round(1 / current_est[0] / 4 / 0.002) * 0.002
        eps2_new = heuristic(eps2, tp_est)
        print("{}: {} : {}".format(idx_eps, heuristic.name, eps2_new[0])), np.round(1000 * np.sqrt(np.diag(updater.est_covariance_mtx())))
        # now both the experiment and the simulation are done, do the update
        updater.update(outcome, eps2)
        eps2 = eps2_new
        
        # store info
        for idx_h, h in enumerate(heuristics_hal[-1]):
            track_means_lah[idx_trial,idx_h, idx_eps, :] = h.updater.est_mean()
            track_covs_lah[idx_trial,idx_h, idx_eps, :, :] = h.updater.est_covariance_mtx()
        
        print "---"
# Out:
# Starting Trial 0
# =================
# 0: Bayes Risk: Alternating     : ( 0.03,  0.,  0.,  0., 0, 10) [ 2896.  2887.  2852.   575.   293.]
# 0: Bayes Risk: Old Information : ( 0.03,  0.,  0.,  0., 0, 10) [ 2869.  2913.  2901.   577.   276.]
# 0: Bayes Risk: Look-Ahead      : ( 0.03,  0.,  0.,  0., 0, 10) [ 2857.  2893.  2938.   582.   284.]
# ---
# 1: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [ 1409.  2850.  3107.   577.   279.]
# 1: Bayes Risk: Old Information : ( 0.05,  0.,  0.,  0., 0, 10) [ 1278.  2846.  2980.   566.   276.]
# 1: Bayes Risk: Look-Ahead      : ( 0.12,  0.,  0.,  0., 0, 10) [  957.  2848.  2953.   575.   272.]
# ---
# 2: Bayes Risk: Alternating     : ( 0.15,  0.,  0.,  0., 0, 10) [ 1034.  2677.  2580.   575.   289.]
# 2: Bayes Risk: Old Information : ( 0.1,  0.,  0.,  0., 0, 10) [ 1007.  2930.  3036.   578.   263.]
# 2: Bayes Risk: Look-Ahead      : ( 0.15,  0.,  0.,  0., 0, 10) [ 1017.  2779.  3151.   570.   261.]
# ---
# 3: Bayes Risk: Alternating     : ( 0.17,  0.,  0.,  0., 0, 10) [  942.  2335.  2274.   558.   287.]
# 3: Bayes Risk: Old Information : ( 0.15,  0.,  0.,  0., 0, 10) [  828.  2637.  2587.   566.   270.]
# 3: Bayes Risk: Look-Ahead      : ( 0.05,  0.,  0.,  0., 0, 10) [ 1836.  2989.  2947.   581.   249.]
# ---
# 4: Bayes Risk: Alternating     : ( 0.17,  0.,  0.,  0., 0, 10) [  835.  2132.  2159.   511.   279.]
# 4: Bayes Risk: Old Information : ( 0.16,  0.,  0.,  0., 0, 10) [  741.  2055.  2272.   596.   265.]
# 4: Bayes Risk: Look-Ahead      : ( 0.02,  0.,  0.,  0., 0, 10) [ 1869.  2358.  2838.   589.   254.]
# ---
# 5: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [  841.  2106.  2222.   513.   275.]
# 5: Bayes Risk: Old Information : ( 0.07,  0.,  0.,  0., 0, 10) [  476.  1524.  2310.   607.   264.]
# 5: Bayes Risk: Look-Ahead      : ( 0.17,  0.,  0.,  0., 0, 10) [  898.  1607.  2057.   590.   236.]
# ---
# 6: Bayes Risk: Alternating     : ( 0.22,  0.,  0.,  0., 0, 10) [  610.  1877.  2030.   508.   274.]
# 6: Bayes Risk: Old Information : ( 0.08,  0.,  0.,  0., 0, 10) [  460.  1340.  2264.   588.   254.]
# 6: Bayes Risk: Look-Ahead      : ( 0.17,  0.,  0.,  0., 0, 10) [  398.  1226.  1864.   597.   239.]
# ---
# 7: Bayes Risk: Alternating     : ( 0.13,  0.,  0.,  0., 0, 10) [  342.  1044.  1686.   476.   270.]
# 7: Bayes Risk: Old Information : ( 0.08,  0.,  0.,  0., 0, 10) [  348.  1118.  2182.   614.   252.]
# 7: Bayes Risk: Look-Ahead      : ( 0.12,  0.,  0.,  0., 0, 10) [  301.   909.  1807.   578.   236.]
# ---
# 8: Bayes Risk: Alternating     : ( 0.046,  0.12,  0.,  0., 1, 10) [  280.   824.  1637.   470.   263.]
# 8: Bayes Risk: Old Information : ( 0.04,  0.,  0.,  0., 0, 10) [  315.  1028.  2127.   630.   251.]
# 8: Bayes Risk: Look-Ahead      : ( 0.12,  0.,  0.,  0., 0, 10) [  306.   871.  1827.   572.   234.]
# ---
# 9: Bayes Risk: Alternating     : ( 0.046,  0.16,  0.,  0., 1, 10) [  321.   968.  1675.   537.   272.]
# 9: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  279.   814.  2069.   588.   244.]
# 9: Bayes Risk: Look-Ahead      : ( 0.23,  0.,  0.,  0., 0, 10) [  287.   792.  1753.   566.   234.]
# ---
# 10: Bayes Risk: Alternating     : ( 0.12,  0.,  0.,  0., 0, 10) [  282.   931.  1687.   267.   267.]
# 10: Bayes Risk: Old Information : ( 0.042,  0.12,  0.,  0., 1, 10) [  259.   759.  1708.   580.   246.]
# 10: Bayes Risk: Look-Ahead      : ( 0.23,  0.,  0.,  0., 0, 10) [  276.   757.  1714.   561.   234.]
# ---
# 11: Bayes Risk: Alternating     : ( 0.13,  0.,  0.,  0., 0, 10) [  237.  1097.  1849.   310.   265.]
# 11: Bayes Risk: Old Information : ( 0.044,  0.16,  0.,  0., 1, 10) [  180.   715.  1838.   568.   224.]
# 11: Bayes Risk: Look-Ahead      : ( 0.044,  0.12,  0.,  0., 1, 10) [  224.   690.  1910.   550.   234.]
# ---
# 12: Bayes Risk: Alternating     : ( 0.47,  0.,  0.,  0., 0, 10) [  257.   579.  1674.   269.   280.]
# 12: Bayes Risk: Old Information : ( 0.044,  0.16,  0.,  0., 1, 10) [  175.   736.  1941.   574.   232.]
# 12: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  215.   668.  1629.   552.   218.]
# ---
# 13: Bayes Risk: Alternating     : ( 0.046,  0.36,  0.,  0., 1, 10) [  282.   681.  1800.   283.   268.]
# 13: Bayes Risk: Old Information : ( 0.39,  0.,  0.,  0., 0, 10) [  168.   779.  1976.   506.   223.]
# 13: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  207.   343.  1577.   371.   197.]
# ---
# 14: Bayes Risk: Alternating     : ( 0.12,  0.,  0.,  0., 0, 10) [  272.   528.  1619.   208.   247.]
# 14: Bayes Risk: Old Information : ( 0.39,  0.,  0.,  0., 0, 10) [  170.   817.  2053.   514.   226.]
# 14: Bayes Risk: Look-Ahead      : ( 0.47,  0.,  0.,  0., 0, 10) [  216.   418.  1630.   427.   213.]
# ---
# 15: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  264.   408.  1443.   186.   246.]
# 15: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  111.   512.  1292.   401.   184.]
# 15: Bayes Risk: Look-Ahead      : ( 0.046,  0.12,  0.,  0., 1, 10) [  188.   451.  1568.   448.   217.]
# ---
# 16: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [  223.   407.  1397.   190.   245.]
# 16: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [   90.   408.  1039.   325.   169.]
# 16: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [  142.   429.  1536.   435.   220.]
# ---
# 17: Bayes Risk: Alternating     : ( 0.046,  1.08,  0.,  0., 1, 10) [  238.   449.  1437.   217.   244.]
# 17: Bayes Risk: Old Information : ( 0.044,  0.4,  0.,  0., 1, 10) [   92.   410.  1062.   306.   161.]
# 17: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [  150.   455.  1545.   462.   223.]
# ---
# 18: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  236.   384.  1665.   261.   245.]
# 18: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [   92.   397.  1049.   273.   153.]
# 18: Bayes Risk: Look-Ahead      : ( 0.046,  0.28,  0.,  0., 1, 10) [  146.   511.  1439.   503.   219.]
# ---
# 19: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  147.   210.  1845.   210.   205.]
# 19: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [   93.   362.  1046.   216.   144.]
# 19: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  120.   303.  1536.   340.   205.]
# ---
# 20: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  110.   145.  1813.   156.   137.]
# 20: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [   67.   266.  1109.   211.   124.]
# 20: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  122.   302.  1582.   347.   206.]
# ---
# 21: Bayes Risk: Alternating     : ( 0.04,  0.,  0.,  0., 0, 10) [  107.   140.  1767.   143.   121.]
# 21: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [   57.   167.  1118.   177.   117.]
# 21: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [  108.   298.  1458.   349.   209.]
# ---
# 22: Bayes Risk: Alternating     : ( 0.04,  0.,  0.,  0., 0, 10) [  105.   139.  1756.   140.   120.]
# 22: Bayes Risk: Old Information : ( 0.044,  0.6,  0.,  0., 1, 10) [   57.   212.  1016.   193.   116.]
# 22: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [  108.   288.  1249.   333.   206.]
# ---
# 23: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [   96.   140.  1745.   145.   123.]
# 23: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  54.  131.  937.  141.  104.]
# 23: Bayes Risk: Look-Ahead      : ( 0.046,  0.32,  0.,  0., 1, 10) [  118.   321.  1315.   305.   199.]
# ---
# 24: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [   94.   136.  1717.   137.   114.]
# 24: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  53.  107.  926.  118.  101.]
# 24: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  119.   277.  1285.   264.   211.]
# ---
# 25: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   95.   150.  1776.   154.   129.]
# 25: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  59.   93.  985.  106.   99.]
# 25: Bayes Risk: Look-Ahead      : ( 0.046,  0.2,  0.,  0., 1, 10) [  110.   268.  1265.   253.   210.]
# ---
# 26: Bayes Risk: Alternating     : ( 0.046,  1.12,  0.,  0., 1, 10) [   94.   135.  1767.   141.   129.]
# 26: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  55.   98.  946.  113.   98.]
# 26: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   91.   247.  1237.   247.   211.]
# ---
# 27: Bayes Risk: Alternating     : ( 0.046,  0.72,  0.,  0., 1, 10) [   94.   139.  1757.   135.   124.]
# 27: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  56.  113.  913.  132.   99.]
# 27: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   86.   246.  1197.   261.   213.]
# ---
# 28: Bayes Risk: Alternating     : ( 0.046,  0.56,  0.,  0., 1, 10) [   90.   110.  1737.   132.   129.]
# 28: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  55.  104.  906.  117.   98.]
# 28: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   86.   237.  1228.   244.   208.]
# ---
# 29: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [   87.   140.  1787.   182.   144.]
# 29: Bayes Risk: Old Information : ( 0.044,  0.24,  0.,  0., 1, 10) [  55.  115.  919.  126.  102.]
# 29: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   85.   228.  1249.   233.   208.]
# ---
# 30: Bayes Risk: Alternating     : ( 0.45,  0.,  0.,  0., 0, 10) [   76.   145.  1674.   171.   141.]
# 30: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  54.  106.  911.  113.  101.]
# 30: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [   81.   215.  1235.   225.   207.]
# ---
# 31: Bayes Risk: Alternating     : ( 0.046,  0.56,  0.,  0., 1, 10) [   69.   142.  1605.   138.   133.]
# 31: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  53.   83.  889.   80.   99.]
# 31: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [   80.   210.  1224.   222.   206.]
# ---
# 32: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   73.   171.  1672.   166.   139.]
# 32: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  52.   81.  921.   77.   99.]
# 32: Bayes Risk: Look-Ahead      : ( 0.45,  0.,  0.,  0., 0, 10) [   79.   202.  1231.   222.   207.]
# ---
# 33: Bayes Risk: Alternating     : ( 0.046,  0.68,  0.,  0., 1, 10) [   65.   148.  1427.   152.   139.]
# 33: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  52.   81.  899.   77.   99.]
# 33: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   80.   194.  1235.   207.   208.]
# ---
# 34: Bayes Risk: Alternating     : ( 0.046,  1.,  0.,  0., 1, 10) [   59.   163.  1524.   143.   123.]
# 34: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  51.   81.  903.   76.   98.]
# 34: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   79.   184.  1245.   200.   206.]
# ---
# 35: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   60.   161.  1520.   171.   127.]
# 35: Bayes Risk: Old Information : ( 0.044,  0.6,  0.,  0., 1, 10) [  52.   82.  858.   77.   97.]
# 35: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   78.   217.  1232.   227.   194.]
# ---
# 36: Bayes Risk: Alternating     : ( 0.046,  0.72,  0.,  0., 1, 10) [   60.   157.  1383.   136.   128.]
# 36: Bayes Risk: Old Information : ( 0.044,  0.6,  0.,  0., 1, 10) [  48.   82.  867.   78.   96.]
# 36: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   78.   202.  1297.   210.   193.]
# ---
# 37: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [   61.   137.  1463.   134.   135.]
# 37: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  48.   66.  799.   62.   93.]
# 37: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   78.   198.  1306.   207.   191.]
# ---
# 38: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [   64.   146.  1624.   151.   133.]
# 38: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  47.   58.  746.   53.   89.]
# 38: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   76.   202.  1256.   214.   191.]
# ---
# 39: Bayes Risk: Alternating     : ( 0.046,  0.56,  0.,  0., 1, 10) [   66.   147.  1707.   157.   131.]
# 39: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  47.   58.  725.   54.   89.]
# 39: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   77.   197.  1293.   206.   188.]
# ---
# 40: Bayes Risk: Alternating     : ( 0.046,  0.56,  0.,  0., 1, 10) [   59.   198.  1732.   196.   138.]
# 40: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  47.   58.  728.   53.   88.]
# 40: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [   78.   194.  1314.   201.   183.]
# ---
# 41: Bayes Risk: Alternating     : ( 0.046,  0.68,  0.,  0., 1, 10) [   59.   185.  1736.   212.   135.]
# 41: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  47.   57.  730.   52.   88.]
# 41: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [   79.   194.  1314.   199.   181.]
# ---
# 42: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   61.   178.  1766.   188.   132.]
# 42: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  45.   55.  771.   50.   88.]
# 42: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  56.  103.  936.   99.  165.]
# ---
# 43: Bayes Risk: Alternating     : ( 0.046,  1.04,  0.,  0., 1, 10) [   56.   154.  1497.   164.   133.]
# 43: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  45.   56.  754.   50.   87.]
# 43: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  52.   67.  807.   67.  147.]
# ---
# 44: Bayes Risk: Alternating     : ( 0.046,  0.56,  0.,  0., 1, 10) [   55.   148.  1499.   157.   130.]
# 44: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  46.   56.  737.   50.   86.]
# 44: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  52.   68.  882.   68.  152.]
# ---
# 45: Bayes Risk: Alternating     : ( 0.48,  0.,  0.,  0., 0, 10) [   56.   130.  1483.   149.   135.]
# 45: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  45.   55.  756.   49.   87.]
# 45: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [  49.   67.  799.   68.  148.]
# ---
# 46: Bayes Risk: Alternating     : ( 0.046,  0.8,  0.,  0., 1, 10) [   55.   130.  1499.   149.   138.]
# 46: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  43.   55.  745.   49.   87.]
# 46: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  44.   65.  712.   66.  138.]
# ---
# 47: Bayes Risk: Alternating     : ( 0.046,  0.32,  0.,  0., 1, 10) [   54.   122.  1526.   133.   135.]
# 47: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  42.   56.  724.   50.   89.]
# 47: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  44.   61.  717.   64.  135.]
# ---
# 48: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [   63.   169.  1673.   153.   141.]
# 48: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  42.   56.  706.   50.   88.]
# 48: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  43.   59.  729.   63.  130.]
# ---
# 49: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [   62.   153.  1804.   143.   137.]
# 49: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  41.   57.  660.   51.   82.]
# 49: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  43.   58.  728.   63.  128.]
# ---
# 50: Bayes Risk: Alternating     : ( 0.046,  1.16,  0.,  0., 1, 10) [   63.   151.  1751.   143.   136.]
# 50: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   56.  678.   50.   82.]
# 50: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  42.   58.  719.   63.  126.]
# ---
# 51: Bayes Risk: Alternating     : ( 0.046,  0.6,  0.,  0., 1, 10) [   62.   142.  1800.   126.   133.]
# 51: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  41.   58.  644.   52.   81.]
# 51: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  42.   58.  719.   63.  125.]
# ---
# 52: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   59.    96.  1610.    89.   133.]
# 52: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   56.  667.   50.   82.]
# 52: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  42.   57.  708.   62.  123.]
# ---
# 53: Bayes Risk: Alternating     : ( 0.42,  0.,  0.,  0., 0, 10) [   61.    52.  1544.    73.   135.]
# 53: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   56.  671.   50.   81.]
# 53: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [  43.   59.  722.   63.  125.]
# ---
# 54: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   61.    50.  1391.    73.   134.]
# 54: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  41.   57.  639.   51.   80.]
# 54: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [  43.   60.  716.   63.  126.]
# ---
# 55: Bayes Risk: Alternating     : ( 0.046,  0.6,  0.,  0., 1, 10) [   61.    53.  1417.    72.   132.]
# 55: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   55.  679.   48.   81.]
# 55: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [  44.   57.  724.   63.  125.]
# ---
# 56: Bayes Risk: Alternating     : ( 0.046,  0.64,  0.,  0., 1, 10) [   62.    60.  1511.    75.   126.]
# 56: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  39.   54.  716.   47.   83.]
# 56: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  49.   77.  848.   78.  138.]
# ---
# 57: Bayes Risk: Alternating     : ( 0.046,  0.64,  0.,  0., 1, 10) [   59.    55.  1338.    81.   133.]
# 57: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   55.  669.   48.   80.]
# 57: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  44.   55.  735.   60.  124.]
# ---
# 58: Bayes Risk: Alternating     : ( 0.046,  1.12,  0.,  0., 1, 10) [  47.   39.  984.   60.  132.]
# 58: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   56.  639.   50.   79.]
# 58: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  42.   55.  688.   61.  122.]
# ---
# 59: Bayes Risk: Alternating     : ( 0.046,  1.12,  0.,  0., 1, 10) [  47.   38.  921.   52.  125.]
# 59: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   55.  643.   49.   79.]
# 59: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  44.   55.  714.   60.  123.]
# ---
# 60: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  41.   26.  720.   33.   96.]
# 60: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   55.  648.   49.   79.]
# 60: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  45.   55.  738.   60.  124.]
# ---
# 61: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  42.   26.  683.   32.   95.]
# 61: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  40.   55.  636.   49.   79.]
# 61: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  46.   55.  729.   60.  125.]
# ---
# 62: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  47.   26.  675.   31.   92.]
# 62: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  39.   55.  640.   48.   79.]
# 62: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  45.   55.  734.   60.  124.]
# ---
# 63: Bayes Risk: Alternating     : ( 0.046,  1.84,  0.,  0., 1, 10) [  48.   25.  671.   31.   93.]
# 63: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  39.   55.  644.   48.   78.]
# 63: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  45.   54.  737.   60.  122.]
# ---
# 64: Bayes Risk: Alternating     : ( 0.45,  0.,  0.,  0., 0, 10) [  52.   28.  733.   29.   96.]
# 64: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  39.   54.  648.   48.   78.]
# 64: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  41.   55.  685.   61.  117.]
# ---
# 65: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [  53.   27.  772.   28.   90.]
# 65: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  39.   55.  636.   48.   78.]
# 65: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  43.   54.  705.   60.  118.]
# ---
# 66: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [  53.   18.  856.   19.   70.]
# 66: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  39.   55.  626.   48.   78.]
# 66: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  44.   48.  726.   58.  119.]
# ---
# 67: Bayes Risk: Alternating     : ( 0.046,  1.52,  0.,  0., 1, 10) [  55.   19.  793.   21.   68.]
# 67: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  38.   55.  639.   48.   77.]
# 67: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  45.   44.  734.   57.  120.]
# ---
# 68: Bayes Risk: Alternating     : ( 0.046,  1.32,  0.,  0., 1, 10) [  55.   18.  769.   20.   63.]
# 68: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  38.   54.  674.   47.   78.]
# 68: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  39.   31.  593.   47.  100.]
# ---
# 69: Bayes Risk: Alternating     : ( 0.046,  1.52,  0.,  0., 1, 10) [  53.   16.  785.   18.   54.]
# 69: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  38.   54.  682.   48.   78.]
# 69: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  39.   28.  582.   43.   91.]
# ---
# 70: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  53.   15.  774.   18.   52.]
# 70: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  36.   54.  659.   47.   77.]
# 70: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  40.   27.  550.   44.   90.]
# ---
# 71: Bayes Risk: Alternating     : ( 0.046,  1.52,  0.,  0., 1, 10) [  52.   15.  766.   18.   52.]
# 71: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  36.   54.  657.   47.   77.]
# 71: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  38.   27.  555.   44.   90.]
# ---
# 72: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  51.   15.  681.   18.   53.]
# 72: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  36.   54.  682.   47.   78.]
# 72: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  33.   28.  581.   43.   90.]
# ---
# 73: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  55.   14.  722.   18.   55.]
# 73: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  35.   54.  694.   48.   79.]
# 73: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  30.   28.  585.   42.   90.]
# ---
# 74: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  51.   15.  692.   18.   53.]
# 74: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  35.   54.  691.   48.   79.]
# 74: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  29.   28.  561.   42.   87.]
# ---
# 75: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  55.   15.  732.   18.   55.]
# 75: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   53.  681.   47.   78.]
# 75: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  29.   27.  536.   41.   84.]
# ---
# 76: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  51.   15.  702.   18.   54.]
# 76: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   53.  685.   47.   79.]
# 76: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  29.   28.  557.   42.   86.]
# ---
# 77: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  47.   15.  669.   18.   53.]
# 77: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  35.   54.  704.   47.   81.]
# 77: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  32.   29.  610.   43.   93.]
# ---
# 78: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  46.   15.  664.   18.   52.]
# 78: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  34.   54.  693.   47.   80.]
# 78: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  32.   30.  621.   44.   95.]
# ---
# 79: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  50.   15.  709.   18.   54.]
# 79: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  34.   49.  674.   44.   74.]
# 79: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  32.   30.  619.   44.   95.]
# ---
# 80: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  46.   15.  676.   18.   53.]
# 80: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [  34.   48.  663.   42.   72.]
# 80: Bayes Risk: Look-Ahead      : ( 0.45,  0.,  0.,  0., 0, 10) [  33.   30.  589.   45.  103.]
# ---
# 81: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [  49.   14.  699.   18.   51.]
# 81: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   48.  665.   41.   72.]
# 81: Bayes Risk: Look-Ahead      : ( 0.45,  0.,  0.,  0., 0, 10) [  33.   30.  589.   45.  102.]
# ---
# 82: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [  47.   13.  696.   17.   46.]
# 82: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   49.  666.   40.   72.]
# 82: Bayes Risk: Look-Ahead      : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   29.  589.   45.  100.]
# ---
# 83: Bayes Risk: Alternating     : ( 0.47,  0.,  0.,  0., 0, 10) [  51.   16.  687.   20.   53.]
# 83: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  33.   49.  661.   40.   72.]
# 83: Bayes Risk: Look-Ahead      : ( 0.45,  0.,  0.,  0., 0, 10) [  34.   29.  588.   46.  100.]
# ---
# 84: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  30.   16.  497.   20.   56.]
# 84: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  33.   49.  655.   40.   72.]
# 84: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  31.   30.  583.   45.  103.]
# ---
# 85: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  27.   16.  484.   20.   55.]
# 85: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  32.   49.  649.   40.   72.]
# 85: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  30.   31.  578.   44.  104.]
# ---
# 86: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  26.   16.  492.   20.   54.]
# 86: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  32.   48.  623.   38.   71.]
# 86: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  31.   31.  594.   45.  106.]
# ---
# 87: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  26.   16.  484.   20.   54.]
# 87: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  32.   47.  605.   37.   69.]
# 87: Bayes Risk: Look-Ahead      : ( 0.044,  1.32,  0.,  0., 1, 10) [  30.   31.  571.   44.  102.]
# ---
# 88: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  25.   16.  492.   20.   54.]
# 88: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  32.   47.  605.   36.   69.]
# 88: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  30.   31.  587.   45.  104.]
# ---
# 89: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  25.   16.  479.   20.   53.]
# 89: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  32.   49.  621.   36.   70.]
# 89: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  28.   24.  539.   31.   85.]
# ---
# 90: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  463.   20.   54.]
# 90: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  30.   48.  592.   35.   69.]
# 90: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  27.   24.  516.   31.   82.]
# ---
# 91: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [  26.   16.  495.   20.   51.]
# 91: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  30.   48.  573.   35.   69.]
# 91: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  28.   24.  534.   31.   84.]
# ---
# 92: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  26.   16.  480.   19.   52.]
# 92: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  30.   51.  620.   35.   74.]
# 92: Bayes Risk: Look-Ahead      : ( 0.044,  1.32,  0.,  0., 1, 10) [  27.   24.  512.   31.   82.]
# ---
# 93: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  448.   19.   55.]
# 93: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  31.   52.  641.   35.   77.]
# 93: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  28.   24.  530.   31.   84.]
# ---
# 94: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  435.   19.   56.]
# 94: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  30.   50.  591.   34.   71.]
# 94: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  29.   29.  567.   39.   95.]
# ---
# 95: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  458.   19.   52.]
# 95: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  30.   50.  589.   33.   71.]
# 95: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  29.   29.  546.   39.   93.]
# ---
# 96: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  433.   19.   55.]
# 96: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  30.   50.  592.   33.   72.]
# 96: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  28.   29.  558.   38.   90.]
# ---
# 97: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  24.   16.  432.   19.   54.]
# 97: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  30.   50.  588.   33.   71.]
# 97: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  28.   29.  557.   38.   89.]
# ---
# 98: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  24.   15.  422.   19.   56.]
# 98: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  29.   50.  577.   33.   69.]
# 98: Bayes Risk: Look-Ahead      : ( 0.044,  1.04,  0.,  0., 1, 10) [  28.   29.  556.   38.   89.]
# ---
# 99: Bayes Risk: Alternating     : ( 0.44,  0.,  0.,  0., 0, 10) [  25.   16.  441.   19.   52.]
# 99: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  29.   50.  566.   33.   68.]
# 99: Bayes Risk: Look-Ahead      : ( 0.044,  1.04,  0.,  0., 1, 10) [  28.   29.  543.   39.   90.]
# ---
# Starting Trial 1
# =================
# 0: Bayes Risk: Alternating     : ( 0.03,  0.,  0.,  0., 0, 10) [ 2874.  2903.  2877.   573.   287.]
# 0: Bayes Risk: Old Information : ( 0.03,  0.,  0.,  0., 0, 10) [ 2883.  2887.  2861.   590.   287.]
# 0: Bayes Risk: Look-Ahead      : ( 0.03,  0.,  0.,  0., 0, 10) [ 2873.  2873.  2900.   581.   289.]
# ---
# 1: Bayes Risk: Alternating     : ( 0.09,  0.,  0.,  0., 0, 10) [ 1339.  2878.  3071.   571.   283.]
# 1: Bayes Risk: Old Information : ( 0.1,  0.,  0.,  0., 0, 10) [ 1146.  2810.  2986.   605.   288.]
# 1: Bayes Risk: Look-Ahead      : ( 0.09,  0.,  0.,  0., 0, 10) [ 1343.  2834.  3097.   572.   281.]
# ---
# 2: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [ 1389.  2785.  3276.   550.   279.]
# 2: Bayes Risk: Old Information : ( 0.1,  0.,  0.,  0., 0, 10) [  881.  2814.  2989.   609.   291.]
# 2: Bayes Risk: Look-Ahead      : ( 0.11,  0.,  0.,  0., 0, 10) [  909.  2866.  3091.   575.   284.]
# ---
# 3: Bayes Risk: Alternating     : ( 0.09,  0.,  0.,  0., 0, 10) [ 1104.  2278.  3196.   553.   279.]
# 3: Bayes Risk: Old Information : ( 0.1,  0.,  0.,  0., 0, 10) [  855.  2622.  2957.   588.   290.]
# 3: Bayes Risk: Look-Ahead      : ( 0.16,  0.,  0.,  0., 0, 10) [  880.  3045.  3083.   573.   286.]
# ---
# 4: Bayes Risk: Alternating     : ( 0.12,  0.,  0.,  0., 0, 10) [ 1058.  2036.  3246.   540.   279.]
# 4: Bayes Risk: Old Information : ( 0.12,  0.,  0.,  0., 0, 10) [  754.  2090.  2998.   607.   275.]
# 4: Bayes Risk: Look-Ahead      : ( 0.16,  0.,  0.,  0., 0, 10) [  899.  2471.  2762.   597.   278.]
# ---
# 5: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [  969.  2056.  3313.   473.   276.]
# 5: Bayes Risk: Old Information : ( 0.12,  0.,  0.,  0., 0, 10) [  755.  2061.  3015.   590.   274.]
# 5: Bayes Risk: Look-Ahead      : ( 0.23,  0.,  0.,  0., 0, 10) [  413.  1117.  2563.   559.   274.]
# ---
# 6: Bayes Risk: Alternating     : ( 0.15,  0.,  0.,  0., 0, 10) [ 1133.  3845.  2842.   405.   260.]
# 6: Bayes Risk: Old Information : ( 0.02,  0.,  0.,  0., 0, 10) [ 1288.  2437.  2530.   611.   268.]
# 6: Bayes Risk: Look-Ahead      : ( 0.23,  0.,  0.,  0., 0, 10) [  419.  1097.  2697.   574.   274.]
# ---
# 7: Bayes Risk: Alternating     : ( 0.16,  0.,  0.,  0., 0, 10) [  512.  1911.  2613.   311.   233.]
# 7: Bayes Risk: Old Information : ( 0.02,  0.,  0.,  0., 0, 10) [ 1752.  2827.  3022.   595.   281.]
# 7: Bayes Risk: Look-Ahead      : ( 0.13,  0.,  0.,  0., 0, 10) [  422.  1107.  2376.   596.   276.]
# ---
# 8: Bayes Risk: Alternating     : ( 0.15,  0.,  0.,  0., 0, 10) [  514.  1879.  2711.   314.   230.]
# 8: Bayes Risk: Old Information : ( 0.19,  0.,  0.,  0., 0, 10) [  457.   961.  1818.   570.   241.]
# 8: Bayes Risk: Look-Ahead      : ( 0.13,  0.,  0.,  0., 0, 10) [  322.   953.  2159.   611.   276.]
# ---
# 9: Bayes Risk: Alternating     : ( 0.21,  0.,  0.,  0., 0, 10) [  836.  3059.  2702.   363.   237.]
# 9: Bayes Risk: Old Information : ( 0.19,  0.,  0.,  0., 0, 10) [  398.   750.  1853.   584.   241.]
# 9: Bayes Risk: Look-Ahead      : ( 0.13,  0.,  0.,  0., 0, 10) [  321.   835.  1972.   595.   274.]
# ---
# 10: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [  828.  2701.  2656.   366.   233.]
# 10: Bayes Risk: Old Information : ( 0.13,  0.,  0.,  0., 0, 10) [  289.   748.  1844.   598.   233.]
# 10: Bayes Risk: Look-Ahead      : ( 0.18,  0.,  0.,  0., 0, 10) [  399.   792.  1814.   531.   261.]
# ---
# 11: Bayes Risk: Alternating     : ( 0.17,  0.,  0.,  0., 0, 10) [  377.  1161.  2744.   358.   221.]
# 11: Bayes Risk: Old Information : ( 0.13,  0.,  0.,  0., 0, 10) [  232.   691.  1879.   601.   233.]
# 11: Bayes Risk: Look-Ahead      : ( 0.05,  0.,  0.,  0., 0, 10) [  495.   810.  1562.   434.   255.]
# ---
# 12: Bayes Risk: Alternating     : ( 0.45,  0.,  0.,  0., 0, 10) [  343.  1139.  2806.   369.   218.]
# 12: Bayes Risk: Old Information : ( 0.23,  0.,  0.,  0., 0, 10) [  245.   704.  1951.   604.   234.]
# 12: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [  210.   500.  1518.   409.   251.]
# ---
# 13: Bayes Risk: Alternating     : ( 0.046,  0.2,  0.,  0., 1, 10) [  218.   760.  2583.   386.   200.]
# 13: Bayes Risk: Old Information : ( 0.23,  0.,  0.,  0., 0, 10) [  266.   771.  2123.   633.   242.]
# 13: Bayes Risk: Look-Ahead      : ( 0.25,  0.,  0.,  0., 0, 10) [  177.   496.  1347.   419.   254.]
# ---
# 14: Bayes Risk: Alternating     : ( 0.29,  0.,  0.,  0., 0, 10) [  219.   748.  2404.   428.   198.]
# 14: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  253.   687.  1923.   599.   231.]
# 14: Bayes Risk: Look-Ahead      : ( 0.046,  0.24,  0.,  0., 1, 10) [  174.   337.  1432.   358.   246.]
# ---
# 15: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [  212.   772.  2392.   414.   200.]
# 15: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  221.   688.  1769.   596.   230.]
# 15: Bayes Risk: Look-Ahead      : ( 0.046,  0.2,  0.,  0., 1, 10) [  159.   360.  1359.   379.   244.]
# ---
# 16: Bayes Risk: Alternating     : ( 0.48,  0.,  0.,  0., 0, 10) [  159.   551.  2011.   404.   195.]
# 16: Bayes Risk: Old Information : ( 0.046,  0.2,  0.,  0., 1, 10) [  198.   327.  2097.   297.   253.]
# 16: Bayes Risk: Look-Ahead      : ( 0.046,  0.52,  0.,  0., 1, 10) [  152.   380.  1213.   385.   260.]
# ---
# 17: Bayes Risk: Alternating     : ( 0.046,  0.16,  0.,  0., 1, 10) [  106.   363.  2023.   349.   175.]
# 17: Bayes Risk: Old Information : ( 0.046,  0.32,  0.,  0., 1, 10) [  203.   371.  2154.   335.   238.]
# 17: Bayes Risk: Look-Ahead      : ( 0.48,  0.,  0.,  0., 0, 10) [  157.   426.  1178.   440.   275.]
# ---
# 18: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [  105.   211.  1889.   256.   160.]
# 18: Bayes Risk: Old Information : ( 0.046,  0.32,  0.,  0., 1, 10) [  202.   367.  2132.   319.   239.]
# 18: Bayes Risk: Look-Ahead      : ( 0.48,  0.,  0.,  0., 0, 10) [  159.   441.  1175.   448.   274.]
# ---
# 19: Bayes Risk: Alternating     : ( 0.046,  0.32,  0.,  0., 1, 10) [   97.   207.  1668.   260.   158.]
# 19: Bayes Risk: Old Information : ( 0.046,  0.28,  0.,  0., 1, 10) [  195.   332.  2106.   316.   245.]
# 19: Bayes Risk: Look-Ahead      : ( 0.046,  0.12,  0.,  0., 1, 10) [  107.   308.  1103.   353.   266.]
# ---
# 20: Bayes Risk: Alternating     : ( 0.046,  0.2,  0.,  0., 1, 10) [   97.   222.  1717.   255.   170.]
# 20: Bayes Risk: Old Information : ( 0.046,  0.28,  0.,  0., 1, 10) [  189.   290.  2117.   292.   250.]
# 20: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [  102.   287.  1116.   334.   261.]
# ---
# 21: Bayes Risk: Alternating     : ( 0.046,  0.44,  0.,  0., 1, 10) [   91.   218.  1647.   274.   167.]
# 21: Bayes Risk: Old Information : ( 0.4,  0.,  0.,  0., 0, 10) [  182.   300.  2177.   302.   255.]
# 21: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   99.   264.  1111.   287.   261.]
# ---
# 22: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   88.   132.  1843.   181.   175.]
# 22: Bayes Risk: Old Information : ( 0.46,  0.,  0.,  0., 0, 10) [  192.   267.  2012.   260.   236.]
# 22: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   95.   221.  1263.   224.   247.]
# ---
# 23: Bayes Risk: Alternating     : ( 0.42,  0.,  0.,  0., 0, 10) [   89.   139.  1871.   172.   178.]
# 23: Bayes Risk: Old Information : ( 0.046,  0.36,  0.,  0., 1, 10) [  141.   209.  1712.   221.   221.]
# 23: Bayes Risk: Look-Ahead      : ( 0.43,  0.,  0.,  0., 0, 10) [   94.   169.  1277.   171.   216.]
# ---
# 24: Bayes Risk: Alternating     : ( 0.046,  0.28,  0.,  0., 1, 10) [   80.   134.  1568.   174.   179.]
# 24: Bayes Risk: Old Information : ( 0.046,  0.8,  0.,  0., 1, 10) [  115.   221.  1732.   232.   222.]
# 24: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [   99.   168.  1294.   171.   213.]
# ---
# 25: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   76.   139.  1552.   169.   180.]
# 25: Bayes Risk: Old Information : ( 0.046,  0.92,  0.,  0., 1, 10) [  111.   216.  1663.   226.   211.]
# 25: Bayes Risk: Look-Ahead      : ( 0.44,  0.,  0.,  0., 0, 10) [  102.   157.  1352.   166.   212.]
# ---
# 26: Bayes Risk: Alternating     : ( 0.046,  0.32,  0.,  0., 1, 10) [   80.   140.  1552.   166.   179.]
# 26: Bayes Risk: Old Information : ( 0.046,  0.96,  0.,  0., 1, 10) [  110.   232.  1701.   234.   214.]
# 26: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  113.   171.  1230.   180.   213.]
# ---
# 27: Bayes Risk: Alternating     : ( 0.046,  0.2,  0.,  0., 1, 10) [   80.   124.  1686.   136.   188.]
# 27: Bayes Risk: Old Information : ( 0.046,  0.96,  0.,  0., 1, 10) [  109.   241.  1643.   236.   208.]
# 27: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   84.   139.  1392.   156.   200.]
# ---
# 28: Bayes Risk: Alternating     : ( 0.046,  0.2,  0.,  0., 1, 10) [   83.   115.  1727.   139.   190.]
# 28: Bayes Risk: Old Information : ( 0.41,  0.,  0.,  0., 0, 10) [  111.   265.  1736.   267.   208.]
# 28: Bayes Risk: Look-Ahead      : ( 0.046,  0.44,  0.,  0., 1, 10) [   67.   141.  1196.   151.   184.]
# ---
# 29: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [   85.   110.  1750.   141.   192.]
# 29: Bayes Risk: Old Information : ( 0.41,  0.,  0.,  0., 0, 10) [  112.   269.  1744.   270.   207.]
# 29: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [   61.    92.  1139.   106.   164.]
# ---
# 30: Bayes Risk: Alternating     : ( 0.046,  0.16,  0.,  0., 1, 10) [   89.   107.  1811.   143.   192.]
# 30: Bayes Risk: Old Information : ( 0.046,  0.12,  0.,  0., 1, 10) [  109.   276.  1570.   275.   202.]
# 30: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [   71.   137.  1241.   149.   185.]
# ---
# 31: Bayes Risk: Alternating     : ( 0.046,  0.2,  0.,  0., 1, 10) [   88.   101.  1796.   137.   192.]
# 31: Bayes Risk: Old Information : ( 0.4,  0.,  0.,  0., 0, 10) [  115.   284.  1728.   286.   203.]
# 31: Bayes Risk: Look-Ahead      : ( 0.046,  0.68,  0.,  0., 1, 10) [   64.   137.  1142.   146.   183.]
# ---
# 32: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   87.    98.  1786.   137.   194.]
# 32: Bayes Risk: Old Information : ( 0.046,  0.52,  0.,  0., 1, 10) [  109.   261.  1568.   275.   197.]
# 32: Bayes Risk: Look-Ahead      : ( 0.046,  0.84,  0.,  0., 1, 10) [  53.   57.  860.   68.  148.]
# ---
# 33: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   86.    97.  1770.   131.   194.]
# 33: Bayes Risk: Old Information : ( 0.046,  0.52,  0.,  0., 1, 10) [  101.   209.  1491.   231.   202.]
# 33: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  54.   52.  866.   63.  150.]
# ---
# 34: Bayes Risk: Alternating     : ( 0.43,  0.,  0.,  0., 0, 10) [   81.   103.  1771.   135.   189.]
# 34: Bayes Risk: Old Information : ( 0.046,  0.52,  0.,  0., 1, 10) [   97.   238.  1433.   254.   209.]
# 34: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  52.   42.  844.   47.  133.]
# ---
# 35: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   79.   105.  1682.   137.   188.]
# 35: Bayes Risk: Old Information : ( 0.046,  0.4,  0.,  0., 1, 10) [   96.   239.  1424.   259.   210.]
# 35: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  50.   42.  871.   47.  131.]
# ---
# 36: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [   78.   100.  1667.   127.   192.]
# 36: Bayes Risk: Old Information : ( 0.046,  0.52,  0.,  0., 1, 10) [   94.   234.  1428.   246.   210.]
# 36: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  55.   41.  987.   45.  127.]
# ---
# 37: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [   77.   103.  1547.   127.   186.]
# 37: Bayes Risk: Old Information : ( 0.046,  0.52,  0.,  0., 1, 10) [   94.   227.  1413.   236.   203.]
# 37: Bayes Risk: Look-Ahead      : ( 0.044,  0.6,  0.,  0., 1, 10) [  50.   41.  919.   44.  128.]
# ---
# 38: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [   75.   106.  1437.   128.   182.]
# 38: Bayes Risk: Old Information : ( 0.42,  0.,  0.,  0., 0, 10) [   96.   230.  1400.   258.   204.]
# 38: Bayes Risk: Look-Ahead      : ( 0.044,  0.6,  0.,  0., 1, 10) [  50.   41.  923.   44.  127.]
# ---
# 39: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   78.    99.  1611.   123.   190.]
# 39: Bayes Risk: Old Information : ( 0.046,  0.68,  0.,  0., 1, 10) [   95.   225.  1402.   248.   203.]
# 39: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [   53.    41.  1028.    46.   123.]
# ---
# 40: Bayes Risk: Alternating     : ( 0.046,  0.24,  0.,  0., 1, 10) [   77.   102.  1624.   127.   188.]
# 40: Bayes Risk: Old Information : ( 0.046,  0.68,  0.,  0., 1, 10) [   90.   221.  1407.   245.   204.]
# 40: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  52.   37.  996.   41.  119.]
# ---
# 41: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [   77.    99.  1609.   121.   189.]
# 41: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [   89.   224.  1393.   235.   199.]
# 41: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  50.   38.  957.   41.  120.]
# ---
# 42: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   76.   101.  1513.   122.   185.]
# 42: Bayes Risk: Old Information : ( 0.046,  0.4,  0.,  0., 1, 10) [   91.   232.  1344.   242.   210.]
# 42: Bayes Risk: Look-Ahead      : ( 0.41,  0.,  0.,  0., 0, 10) [  50.   38.  964.   41.  119.]
# ---
# 43: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   70.   102.  1363.   119.   173.]
# 43: Bayes Risk: Old Information : ( 0.29,  0.,  0.,  0., 0, 10) [   92.   238.  1244.   250.   183.]
# 43: Bayes Risk: Look-Ahead      : ( 0.046,  0.84,  0.,  0., 1, 10) [  49.   38.  937.   41.  120.]
# ---
# 44: Bayes Risk: Alternating     : ( 0.47,  0.,  0.,  0., 0, 10) [   69.   116.  1248.   147.   159.]
# 44: Bayes Risk: Old Information : ( 0.05,  0.,  0.,  0., 0, 10) [   94.   259.  1296.   256.   190.]
# 44: Bayes Risk: Look-Ahead      : ( 0.046,  0.84,  0.,  0., 1, 10) [  47.   38.  916.   41.  121.]
# ---
# 45: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   63.   116.  1245.   145.   159.]
# 45: Bayes Risk: Old Information : ( 0.046,  0.64,  0.,  0., 1, 10) [   84.   247.  1231.   260.   185.]
# 45: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  48.   37.  935.   38.  114.]
# ---
# 46: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   63.   117.  1253.   146.   160.]
# 46: Bayes Risk: Old Information : ( 0.046,  0.64,  0.,  0., 1, 10) [   81.   243.  1161.   257.   184.]
# 46: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  50.   39.  968.   39.  108.]
# ---
# 47: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [   67.   119.  1353.   148.   170.]
# 47: Bayes Risk: Old Information : ( 0.046,  0.84,  0.,  0., 1, 10) [   60.   198.  1054.   208.   253.]
# 47: Bayes Risk: Look-Ahead      : ( 0.47,  0.,  0.,  0., 0, 10) [  50.   40.  944.   40.  110.]
# ---
# 48: Bayes Risk: Alternating     : ( 0.046,  0.68,  0.,  0., 1, 10) [   67.   119.  1353.   148.   170.]
# 48: Bayes Risk: Old Information : ( 0.046,  0.44,  0.,  0., 1, 10) [  54.  170.  863.  182.  159.]
# 48: Bayes Risk: Look-Ahead      : ( 0.48,  0.,  0.,  0., 0, 10) [  52.   36.  952.   42.  113.]
# ---
# 49: Bayes Risk: Alternating     : ( 0.046,  0.64,  0.,  0., 1, 10) [   66.   110.  1358.   133.   171.]
# 49: Bayes Risk: Old Information : ( 0.046,  1.12,  0.,  0., 1, 10) [  54.  146.  843.  157.  133.]
# 49: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  43.   35.  801.   40.  112.]
# ---
# 50: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [   57.    55.  1295.    67.   141.]
# 50: Bayes Risk: Old Information : ( 0.046,  1.8,  0.,  0., 1, 10) [  51.   57.  802.   62.  109.]
# 50: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  40.   34.  762.   39.  111.]
# ---
# 51: Bayes Risk: Alternating     : ( 0.45,  0.,  0.,  0., 0, 10) [   56.    56.  1226.    68.   141.]
# 51: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  51.   52.  803.   58.  103.]
# 51: Bayes Risk: Look-Ahead      : ( 0.046,  0.6,  0.,  0., 1, 10) [  41.   32.  775.   39.  111.]
# ---
# 52: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [   52.    46.  1364.    59.   130.]
# 52: Bayes Risk: Old Information : ( 0.046,  1.52,  0.,  0., 1, 10) [  48.   52.  796.   61.  119.]
# 52: Bayes Risk: Look-Ahead      : ( 0.046,  1.32,  0.,  0., 1, 10) [  41.   30.  783.   38.  111.]
# ---
# 53: Bayes Risk: Alternating     : ( 0.046,  0.4,  0.,  0., 1, 10) [   58.    46.  1582.    61.   132.]
# 53: Bayes Risk: Old Information : ( 0.046,  1.52,  0.,  0., 1, 10) [  46.   51.  764.   60.  118.]
# 53: Bayes Risk: Look-Ahead      : ( 0.046,  1.32,  0.,  0., 1, 10) [  42.   30.  824.   39.  110.]
# ---
# 54: Bayes Risk: Alternating     : ( 0.41,  0.,  0.,  0., 0, 10) [   56.    36.  1669.    56.   129.]
# 54: Bayes Risk: Old Information : ( 0.046,  1.52,  0.,  0., 1, 10) [  48.   41.  776.   48.   97.]
# 54: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  41.   27.  806.   36.  106.]
# ---
# 55: Bayes Risk: Alternating     : ( 0.046,  1.88,  0.,  0., 1, 10) [   57.    36.  1713.    56.   130.]
# 55: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  48.   38.  775.   44.   90.]
# 55: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  40.   24.  761.   32.  101.]
# ---
# 56: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [   56.    37.  1712.    56.   131.]
# 56: Bayes Risk: Old Information : ( 0.41,  0.,  0.,  0., 0, 10) [  49.   33.  773.   38.   78.]
# 56: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  40.   23.  762.   31.   95.]
# ---
# 57: Bayes Risk: Alternating     : ( 0.046,  1.88,  0.,  0., 1, 10) [   57.    38.  1681.    57.   129.]
# 57: Bayes Risk: Old Information : ( 0.43,  0.,  0.,  0., 0, 10) [  47.   31.  823.   36.   75.]
# 57: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  40.   23.  763.   31.   91.]
# ---
# ...
# 82: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  28.   37.  463.   41.   81.]
# 82: Bayes Risk: Look-Ahead      : ( 0.032,  0.44,  0.,  0., 1, 10) [ 106.  138.  314.   98.  106.]
# ---
# 83: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  23.   36.  611.   39.   76.]
# 83: Bayes Risk: Old Information : ( 0.4,  0.,  0.,  0., 0, 10) [  28.   37.  453.   42.   82.]
# 83: Bayes Risk: Look-Ahead      : ( 0.032,  0.44,  0.,  0., 1, 10) [ 106.  138.  318.   98.  100.]
# ---
# 84: Bayes Risk: Alternating     : ( 0.046,  0.84,  0.,  0., 1, 10) [  23.   35.  613.   39.   76.]
# 84: Bayes Risk: Old Information : ( 0.046,  1.04,  0.,  0., 1, 10) [  28.   37.  444.   42.   82.]
# 84: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [ 105.  115.  318.   85.  101.]
# ---
# 85: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  23.   35.  617.   37.   73.]
# 85: Bayes Risk: Old Information : ( 0.046,  1.,  0.,  0., 1, 10) [  27.   37.  424.   42.   78.]
# 85: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [ 101.   88.  302.   71.  101.]
# ---
# 86: Bayes Risk: Alternating     : ( 0.046,  1.32,  0.,  0., 1, 10) [  22.   35.  614.   38.   74.]
# 86: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   37.  427.   41.   79.]
# 86: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  99.   88.  271.   70.  103.]
# ---
# 87: Bayes Risk: Alternating     : ( 0.046,  2.,  0.,  0., 1, 10) [  22.   27.  595.   30.   71.]
# 87: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   37.  425.   40.   79.]
# 87: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  98.   89.  267.   70.  102.]
# ---
# 88: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  22.   25.  594.   29.   68.]
# 88: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   38.  425.   41.   79.]
# 88: Bayes Risk: Look-Ahead      : ( 0.4,  0.,  0.,  0., 0, 10) [  97.   86.  291.   72.  101.]
# ---
# 89: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  22.   25.  596.   29.   68.]
# 89: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   37.  423.   40.   79.]
# 89: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  99.   93.  220.   67.  103.]
# ---
# 90: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  21.   25.  594.   29.   68.]
# 90: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  26.   37.  421.   40.   78.]
# 90: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [ 100.   91.  251.   63.  100.]
# ---
# 91: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  21.   25.  596.   29.   68.]
# 91: Bayes Risk: Old Information : ( 0.44,  0.,  0.,  0., 0, 10) [  26.   36.  420.   40.   78.]
# 91: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [ 100.   93.  264.   65.  100.]
# ---
# 92: Bayes Risk: Alternating     : ( 0.046,  1.08,  0.,  0., 1, 10) [  21.   25.  597.   29.   67.]
# 92: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   38.  420.   41.   79.]
# 92: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [  98.   92.  244.   63.  102.]
# ---
# 93: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  21.   22.  596.   26.   66.]
# 93: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  27.   39.  413.   41.   80.]
# 93: Bayes Risk: Look-Ahead      : ( 0.032,  0.44,  0.,  0., 1, 10) [  98.   93.  241.   63.  102.]
# ---
# 94: Bayes Risk: Alternating     : ( 0.046,  1.8,  0.,  0., 1, 10) [  21.   22.  600.   26.   64.]
# 94: Bayes Risk: Old Information : ( 0.046,  0.88,  0.,  0., 1, 10) [  27.   41.  415.   43.   82.]
# 94: Bayes Risk: Look-Ahead      : ( 0.032,  0.44,  0.,  0., 1, 10) [  99.   95.  252.   65.   99.]
# ---
# 95: Bayes Risk: Alternating     : ( 0.046,  1.52,  0.,  0., 1, 10) [  21.   21.  601.   26.   62.]
# 95: Bayes Risk: Old Information : ( 0.046,  0.88,  0.,  0., 1, 10) [  27.   40.  414.   43.   81.]
# 95: Bayes Risk: Look-Ahead      : ( 0.032,  0.72,  0.,  0., 1, 10) [  97.   82.  233.   60.  100.]
# ---
# 96: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  21.   20.  602.   24.   61.]
# 96: Bayes Risk: Old Information : ( 0.046,  1.08,  0.,  0., 1, 10) [  26.   29.  380.   31.   66.]
# 96: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  95.   73.  218.   57.   99.]
# ---
# 97: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  21.   20.  601.   25.   61.]
# 97: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  26.   38.  409.   38.   76.]
# 97: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  90.   72.  189.   56.  100.]
# ---
# 98: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  20.   19.  597.   25.   62.]
# 98: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  26.   37.  410.   39.   76.]
# 98: Bayes Risk: Look-Ahead      : ( 0.032,  0.76,  0.,  0., 1, 10) [  91.   73.  172.   56.  101.]
# ---
# 99: Bayes Risk: Alternating     : ( 0.46,  0.,  0.,  0., 0, 10) [  20.   20.  600.   25.   61.]
# 99: Bayes Risk: Old Information : ( 0.45,  0.,  0.,  0., 0, 10) [  26.   38.  411.   39.   76.]
# 99: Bayes Risk: Look-Ahead      : ( 0.032,  0.92,  0.,  0., 1, 10) [  90.   73.  192.   58.   99.]
# ---
# Starting Trial 20
# =================
# 0: Bayes Risk: Alternating     : ( 0.03,  0.,  0.,  0., 0, 10) [ 2910.  2937.  2895.   580.   293.]
# 0: Bayes Risk: Old Information : ( 0.03,  0.,  0.,  0., 0, 10) [ 2920.  2868.  2901.   581.   289.]
# 0: Bayes Risk: Look-Ahead      : ( 0.03,  0.,  0.,  0., 0, 10) [ 2893.  2931.  2894.   575.   287.]
# ---
# 1: Bayes Risk: Alternating     : ( 0.08,  0.,  0.,  0., 0, 10) [  983.  2798.  2576.   580.   289.]
# 1: Bayes Risk: Old Information : ( 0.11,  0.,  0.,  0., 0, 10) [ 1178.  2831.  2938.   594.   281.]
# 1: Bayes Risk: Look-Ahead      : ( 0.08,  0.,  0.,  0., 0, 10) [  986.  2782.  2678.   585.   280.]
# ---
# 2: Bayes Risk: Alternating     : ( 0.13,  0.,  0.,  0., 0, 10) [ 1087.  2407.  2588.   572.   287.]
# 2: Bayes Risk: Old Information : ( 0.15,  0.,  0.,  0., 0, 10) [ 1090.  2801.  2923.   591.   283.]
# 2: Bayes Risk: Look-Ahead      : ( 0.05,  0.,  0.,  0., 0, 10) [ 1238.  2844.  3176.   581.   262.]
# ---
# 3: Bayes Risk: Alternating     : ( 0.05,  0.,  0.,  0., 0, 10) [  693.  1634.  2713.   556.   284.]
# 3: Bayes Risk: Old Information : ( 0.14,  0.,  0.,  0., 0, 10) [ 1342.  2828.  2668.   613.   279.]
# 3: Bayes Risk: Look-Ahead      : ( 0.14,  0.,  0.,  0., 0, 10) [ 1165.  3107.  3169.   580.   262.]
# ---
# 4: Bayes Risk: Alternating     : ( 0.08,  0.,  0.,  0., 0, 10) [  738.  1254.  2722.   511.   279.]
# 4: Bayes Risk: Old Information : ( 0.09,  0.,  0.,  0., 0, 10) [ 1427.  3304.  2607.   612.   286.]
# 4: Bayes Risk: Look-Ahead      : ( 0.15,  0.,  0.,  0., 0, 10) [ 1011.  2859.  2825.   602.   258.]
# ---
# 5: Bayes Risk: Alternating     : ( 0.12,  0.,  0.,  0., 0, 10) [  734.  1187.  2686.   515.   280.]
# 5: Bayes Risk: Old Information : ( 0.03,  0.,  0.,  0., 0, 10) [ 1277.  2864.  2797.   598.   285.]
# 5: Bayes Risk: Look-Ahead      : ( 0.2,  0.,  0.,  0., 0, 10) [ 1156.  3140.  2451.   546.   236.]
# ---
# 6: Bayes Risk: Alternating     : ( 0.07,  0.,  0.,  0., 0, 10) [  643.  1247.  2722.   517.   275.]
# 6: Bayes Risk: Old Information : ( 0.03,  0.,  0.,  0., 0, 10) [ 1467.  3130.  2503.   605.   283.]
# 6: Bayes Risk: Look-Ahead      : ( 0.2,  0.,  0.,  0., 0, 10) [  743.  2168.  2322.   596.   226.]
# ---
# 7: Bayes Risk: Alternating     : ( 0.18,  0.,  0.,  0., 0, 10) [  709.  1348.  2807.   523.   289.]
# 7: Bayes Risk: Old Information : ( 0.02,  0.,  0.,  0., 0, 10) [ 1185.  3195.  2168.   544.   243.]
# 7: Bayes Risk: Look-Ahead      : ( 0.02,  0.,  0.,  0., 0, 10) [  934.  2581.  2667.   601.   237.]
# ---
# 8: Bayes Risk: Alternating     : ( 0.18,  0.,  0.,  0., 0, 10) [  664.  1342.  2945.   514.   292.]
# 8: Bayes Risk: Old Information : ( 0.2,  0.,  0.,  0., 0, 10) [  434.  1397.  1551.   507.   236.]
# 8: Bayes Risk: Look-Ahead      : ( 0.02,  0.,  0.,  0., 0, 10) [ 1101.  3055.  2856.   619.   238.]
# ---
# 9: Bayes Risk: Alternating     : ( 0.07,  0.,  0.,  0., 0, 10) [  633.  1344.  3069.   509.   295.]
# 9: Bayes Risk: Old Information : ( 0.2,  0.,  0.,  0., 0, 10) [  404.  1353.  1535.   508.   238.]
# 9: Bayes Risk: Look-Ahead      : ( 0.15,  0.,  0.,  0., 0, 10) [  628.  2081.  2769.   591.   241.]
# ---
# 10: Bayes Risk: Alternating     : ( 0.18,  0.,  0.,  0., 0, 10) [  658.  1369.  3075.   513.   306.]
# 10: Bayes Risk: Old Information : ( 0.17,  0.,  0.,  0., 0, 10) [  291.  1314.  1695.   538.   241.]
# 10: Bayes Risk: Look-Ahead      : ( 0.23,  0.,  0.,  0., 0, 10) [  510.  1756.  2860.   559.   238.]
# ---
# 11: Bayes Risk: Alternating     : ( 0.35,  0.,  0.,  0., 0, 10) [  592.  1373.  3335.   501.   310.]
# 11: Bayes Risk: Old Information : ( 0.17,  0.,  0.,  0., 0, 10) [  240.  1201.  1757.   541.   239.]
# 11: Bayes Risk: Look-Ahead      : ( 0.17,  0.,  0.,  0., 0, 10) [  512.  1748.  2897.   531.   235.]
# ---
# 12: Bayes Risk: Alternating     : ( 0.36,  0.,  0.,  0., 0, 10) [  585.  1355.  3264.   506.   310.]
# 12: Bayes Risk: Old Information : ( 0.13,  0.,  0.,  0., 0, 10) [  193.   870.  1720.   505.   241.]
# 12: Bayes Risk: Look-Ahead      : ( 0.12,  0.,  0.,  0., 0, 10) [  237.   907.  2285.   503.   219.]
# ---
# 13: Bayes Risk: Alternating     : ( 0.18,  0.,  0.,  0., 0, 10) [  585.  1392.  3261.   519.   306.]
# 13: Bayes Risk: Old Information : ( 0.13,  0.,  0.,  0., 0, 10) [  183.   787.  1696.   484.   240.]
# 13: Bayes Risk: Look-Ahead      : ( 0.26,  0.,  0.,  0., 0, 10) [  212.   794.  2363.   481.   214.]
# ---
# 14: Bayes Risk: Alternating     : ( 0.27,  0.,  0.,  0., 0, 10) [  436.  1187.  3793.   426.   284.]
# 14: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  184.   744.  1702.   493.   238.]
# 14: Bayes Risk: Look-Ahead      : ( 0.046,  0.08,  0.,  0., 1, 10) [  192.   640.  2093.   493.   212.]
# ---
# 15: Bayes Risk: Alternating     : ( 0.26,  0.,  0.,  0., 0, 10) [  443.  1224.  3744.   412.   281.]
# 15: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  183.   715.  1545.   451.   245.]
# 15: Bayes Risk: Look-Ahead      : ( 0.046,  0.24,  0.,  0., 1, 10) [  189.   621.  1998.   499.   215.]
# ---
# 16: Bayes Risk: Alternating     : ( 0.35,  0.,  0.,  0., 0, 10) [  505.  1419.  3483.   402.   277.]
# 16: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  175.   557.  1597.   395.   258.]
# 16: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [  164.   774.  1645.   607.   210.]
# ---
# 17: Bayes Risk: Alternating     : ( 0.14,  0.,  0.,  0., 0, 10) [  527.  1500.  3361.   418.   279.]
# 17: Bayes Risk: Old Information : ( 0.046,  0.2,  0.,  0., 1, 10) [  188.   621.  1634.   408.   254.]
# 17: Bayes Risk: Look-Ahead      : ( 0.48,  0.,  0.,  0., 0, 10) [  170.   820.  1636.   621.   208.]
# ---
# 18: Bayes Risk: Alternating     : ( 0.26,  0.,  0.,  0., 0, 10) [  411.  1144.  3295.   419.   284.]
# 18: Bayes Risk: Old Information : ( 0.046,  0.2,  0.,  0., 1, 10) [  176.   498.  1612.   355.   255.]
# 18: Bayes Risk: Look-Ahead      : ( 0.046,  0.12,  0.,  0., 1, 10) [  118.   714.  1343.   612.   210.]
# ---
# 19: Bayes Risk: Alternating     : ( 0.26,  0.,  0.,  0., 0, 10) [  464.  1299.  3384.   417.   289.]
# 19: Bayes Risk: Old Information : ( 0.38,  0.,  0.,  0., 0, 10) [  178.   517.  1605.   356.   254.]
# 19: Bayes Risk: Look-Ahead      : ( 0.046,  0.08,  0.,  0., 1, 10) [  107.   658.  1348.   557.   200.]
# ---
# 20: Bayes Risk: Alternating     : ( 0.3,  0.,  0.,  0., 0, 10) [  465.  1314.  3404.   403.   289.]
# 20: Bayes Risk: Old Information : ( 0.046,  0.32,  0.,  0., 1, 10) [  177.   512.  1616.   353.   254.]
# 20: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [   99.   561.  1280.   478.   203.]
# ---
# 21: Bayes Risk: Alternating     : ( 0.35,  0.,  0.,  0., 0, 10) [  412.  1092.  3158.   407.   290.]
# 21: Bayes Risk: Old Information : ( 0.044,  0.52,  0.,  0., 1, 10) [  132.   399.  1632.   360.   246.]
# 21: Bayes Risk: Look-Ahead      : ( 0.42,  0.,  0.,  0., 0, 10) [   99.   489.  1255.   394.   205.]
# ---
# 22: Bayes Risk: Alternating     : ( 0.3,  0.,  0.,  0., 0, 10) [  421.  1099.  3110.   410.   290.]
# 22: Bayes Risk: Old Information : ( 0.09,  0.,  0.,  0., 0, 10) [  126.   375.  1688.   351.   246.]
# 22: Bayes Risk: Look-Ahead      : ( 0.046,  0.16,  0.,  0., 1, 10) [   89.   457.  1196.   399.   203.]
# ---
# 23: Bayes Risk: Alternating     : ( 0.4,  0.,  0.,  0., 0, 10) [  422.  1162.  3082.   408.   292.]
# 23: Bayes Risk: Old Information : ( 0.09,  0.,  0.,  0., 0, 10) [  125.   371.  1613.   336.   245.]
# 23: Bayes Risk: Look-Ahead      : ( 0.046,  0.2,  0.,  0., 1, 10) [   84.   447.  1173.   401.   204.]
# ---
# 24: Bayes Risk: Alternating     : ( 0.36,  0.,  0.,  0., 0, 10) [  469.  1281.  3011.   426.   292.]
# 24: Bayes Risk: Old Information : ( 0.41,  0.,  0.,  0., 0, 10) [  125.   362.  1496.   328.   240.]
# 24: Bayes Risk: Look-Ahead      : ( 0.046,  0.48,  0.,  0., 1, 10) [   77.   288.  1132.   254.   192.]
# ---
# 25: Bayes Risk: Alternating     : ( 0.35,  0.,  0.,  0., 0, 10) [  470.  1286.  2939.   443.   299.]
# 25: Bayes Risk: Old Information : ( 0.41,  0.,  0.,  0., 0, 10) [  127.   404.  1432.   371.   241.]
# 25: Bayes Risk: Look-Ahead      : ( 0.046,  0.52,  0.,  0., 1, 10) [   76.   259.  1120.   211.   181.]
# ---
# 26: Bayes Risk: Alternating     : ( 0.26,  0.,  0.,  0., 0, 10) [  403.  1216.  2728.   413.   280.]
# 26: Bayes Risk: Old Information : ( 0.046,  0.32,  0.,  0., 1, 10) [  114.   403.  1265.   373.   246.]
# 26: Bayes Risk: Look-Ahead      : ( 0.046,  0.52,  0.,  0., 1, 10) [   74.   233.  1093.   191.   185.]
# ---
# 27: Bayes Risk: Alternating     : ( 0.35,  0.,  0.,  0., 0, 10) [  460.  1358.  2915.   424.   287.]
# 27: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  103.   386.  1143.   363.   249.]
# 27: Bayes Risk: Look-Ahead      : ( 0.046,  0.52,  0.,  0., 1, 10) [   73.   240.  1080.   193.   181.]
# ---
# 28: Bayes Risk: Alternating     : ( 0.07,  0.,  0.,  0., 0, 10) [  497.  1448.  2959.   448.   294.]
# 28: Bayes Risk: Old Information : ( 0.046,  0.16,  0.,  0., 1, 10) [  103.   378.  1144.   353.   246.]
# 28: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [   74.   231.  1075.   185.   179.]
# ---
# 29: Bayes Risk: Alternating     : ( 0.14,  0.,  0.,  0., 0, 10) [  502.  1437.  2932.   456.   292.]
# 29: Bayes Risk: Old Information : ( 0.46,  0.,  0.,  0., 0, 10) [  102.   197.  1188.   184.   261.]
# 29: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [   73.   233.  1068.   185.   178.]
# ---
# 30: Bayes Risk: Alternating     : ( 0.14,  0.,  0.,  0., 0, 10) [  858.  2361.  3287.   437.   297.]
# 30: Bayes Risk: Old Information : ( 0.47,  0.,  0.,  0., 0, 10) [  104.   238.  1158.   222.   249.]
# 30: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [   68.   202.  1005.   171.   194.]
# ---
# 31: Bayes Risk: Alternating     : ( 0.03,  0.04,  0.,  0., 1, 10) [  818.  2247.  3270.   437.   295.]
# 31: Bayes Risk: Old Information : ( 0.046,  0.68,  0.,  0., 1, 10) [   92.   239.  1152.   220.   250.]
# 31: Bayes Risk: Look-Ahead      : ( 0.46,  0.,  0.,  0., 0, 10) [  67.  190.  981.  165.  190.]
# ---
# 32: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [ 1218.  3334.  2916.   419.   301.]
# 32: Bayes Risk: Old Information : ( 0.044,  0.68,  0.,  0., 1, 10) [   74.   207.  1121.   209.   236.]
# 32: Bayes Risk: Look-Ahead      : ( 0.046,  0.88,  0.,  0., 1, 10) [  67.  178.  968.  158.  188.]
# ---
# 33: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [ 1054.  2939.  2922.   433.   305.]
# 33: Bayes Risk: Old Information : ( 0.044,  0.44,  0.,  0., 1, 10) [   67.   181.  1091.   177.   226.]
# 33: Bayes Risk: Look-Ahead      : ( 0.046,  0.64,  0.,  0., 1, 10) [  61.  188.  909.  168.  178.]
# ---
# 34: Bayes Risk: Alternating     : ( 0.02,  0.,  0.,  0., 0, 10) [ 1320.  3776.  2846.   380.   283.]
# 34: Bayes Risk: Old Information : ( 0.044,  0.64,  0.,  0., 1, 10) [   58.   107.  1044.   107.   201.]

# %%
idx_model = 1
fig=plt.figure(figsize=(10,5))
for idx_h in range(len(heuristics_hal)):
    h = heuristics_hal[0][idx_h]
    plt.semilogy(np.mean(np.sqrt(track_covs_lah[:,idx_h,:,idx_model,idx_model]),axis=0), label=h.name)
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.title('${}$'.format(ham_model.modelparam_names[idx_model]))
plt.xlabel('Experiment #')
plt.ylabel('std (MHz)')
export_figure(fig, 'qhl-lah-we-variance')
# Out:
# Overwriting ../fig/qhl-lah-we-variance.png
# Overwriting ../fig/qhl-lah-we-variance.pdf
